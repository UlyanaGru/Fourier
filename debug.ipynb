# %%
import numpy as np
numstr = 1107
v = 6
filename = f"./data_variousG_6-12/1137_v3.txt"
data = np.loadtxt(filename, delimiter=',')[1:]

# %%
data
# Out:
# array([0.00015539, 0.00015563, 0.00015584, ..., 0.00016855, 0.00016258,
#        0.00015539], shape=(1500,))
